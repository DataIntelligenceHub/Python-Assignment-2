# %%
import numpy as np

# %%
import pandas as pd

# %%
import csv

# %%
mydata = pd.read_csv("/resources/data/hospitaldata.csv")

# %%
mydata
# Out:
#                             Date   id     Time  Age  Sex Consulting..Doctor  \
# 0       Sunday, January 01, 2017  101    11:00   40    F      Dr Kinza Alam
# 1       Monday, January 02, 2017  150  10:45AM   26    M      Nursing Staff
# 2       Monday, January 02, 2017   58  12:38PM   30    F   Dr Riffat Naheed
# 3       Monday, January 02, 2017   75   1:00PM   40    M   Dr Riffat Naheed
# 4       Monday, January 02, 2017   97   2:45PM   27    M   Dr Riffat Naheed
# 5       Monday, January 02, 2017  101   3:00PM   40    F      Dr Kinza Alam
# 6       Monday, January 02, 2017   26   3:28PM   43    M          Dr Saniya
# 7       Monday, January 02, 2017  149   3:45PM   28    F          Dr Fakiha
# 8       Monday, January 02, 2017   20   3:45PM    2    F          Dr Fakiha
# 9       Monday, January 02, 2017   72   5:00PM   40    M          Dr Fakiha
# 10      Monday, January 02, 2017   54   5:00PM   32    F          Dr Saniya
# ...

# %%
list(mydata)
# Out:
# ['Date',
#  'id',
#  'Time',
#  'Age',
#  'Sex',
#  'Consulting..Doctor',
#  'Specialty',
#  'Procedure',
#  'Total..Charges',
#  'Amount..Received.',
#  'Amount..Balance',
#  'Amount.Received.By',
#  'Amount.in.Hospital',
#  'Receptionist..Name',
#  'Next.Apt']

# %%
# question 1
mydata.columns = mydata.columns.str.replace(".","")
list(mydata)
# Out:
# ['Date',
#  'id',
#  'Time',
#  'Age',
#  'Sex',
#  'ConsultingDoctor',
#  'Specialty',
#  'Procedure',
#  'TotalCharges',
#  'AmountReceived',
#  'AmountBalance',
#  'AmountReceivedBy',
#  'AmountinHospital',
#  'ReceptionistName',
#  'NextApt']

# %%
# question 2
sub_mydata = pd.DataFrame(mydata.Date.str.split(',',1).tolist(),columns = ['Day', 'Date'])
most_freq_visit = max(sub_mydata.Day.value_counts().iteritems(), key=lambda x: x[1]) 
print most_freq_visit[0], most_freq_visit[1]
# Out:
# Monday 51

# %%
# question 3
A = mydata['Age']
A.replace('-', 'NA')
avg = pd.to_numeric(A, errors = 'coerce')
print np.mean(avg)
# Out:
# 32.734375

# %%
# question 4
ce = len(list(filter(lambda x: x >= 1 and x <= 12, avg)))
ce
# Out:
# 23

# %%
# question 5
mydata['Sex'] = map(lambda x: str(x).lower(), mydata['Sex'])
mydata.groupby(['Sex']).Specialty.value_counts()
# Out:
# Sex  Specialty
# -    Child Specialist       1
# f    Dentist               57
#      Gynae                 13
#      M/o                    7
#      Orthopedic             5
#      Psychotherapist        4
#      Child Specialist       3
#      Radiologist            3
#      General Surgeon        2
#      Dental                 1
#      ENT                    1
#      Medical Specialist     1
# m    Dentist               46
#      Psychotherapist       10
#      M/o                    8
#      Child Specialist       7
#      Orthopedic             3
#      Radiologist            3
#      General Surgeon        2
#      Medical Specialist     2
#      Anaesthetist           1
#      Dermatologist          1
# Name: Specialty, dtype: int64

# %%
# question 6
mydata['TotalCharges'] = pd.to_numeric(mydata['TotalCharges'], errors='coerce')
print mydata.groupby(['ConsultingDoctor']).TotalCharges.aggregate(np.sum).idxmax(), "earns highest", mydata.groupby(['ConsultingDoctor']).TotalCharges.aggregate(np.sum).max()
# Out:
# Dr Alaf Khan earns highest 513050.0

# %%
# question 7
print mydata.groupby(['Procedure']).TotalCharges.aggregate(np.sum).idxmax(), "earns highest", mydata.groupby(['Procedure']).TotalCharges.aggregate(np.sum).max()
# Out:
# Orthodontics earns highest 240000.0

# %%
# question 8
print mydata.Time.value_counts()
# Out:
# 12:00PM    9
# 1:00PM     9
# 1:30PM     9
# 3:00PM     9
# -          8
# 6:00PM     8
# 2:00PM     6
# 5:30PM     5
# 7:00PM     5
# 5:00PM     5
# 4:30PM     4
# 4:00PM     4
# 2:40PM     4
# 8:00PM     4
# 6:30PM     4
# 6:15PM     4
# 3:45PM     3
# 2:10PM     3
# 11:20AM    3
# 12:40PM    3
# 4:45PM     3
# 3:30PM     3
# 8:30PM     2
# 10:45AM    2
# 1:25PM     2
# 11:30AM    2
# 12:30PM    2
# 1:20PM     2
# 6:10PM     2
# 2:30PM     2
#           ..
# 11:20PM    1
# 10:20AM    1
# 7:45PM     1
# 9:45PM     1
# 6:45PM     1
# 4:50PM     1
# 11:25AM    1
# 10:00PM    1
# 9:00PM     1
# 7:15PM     1
# 9:40PM     1
# 9:00AM     1
# 1:55PM     1
# 12:50PM    1
# 7:10PM     1
# 3:25PM     1
# 10:30PM    1
# 3:15PM     1
# 12:20PM    1
# 10:13AM    1
# 4:20PM     1
# 10:15PM    1
# 1:40PM     1
# 3:40PM     1
# 5:35PM     1
# 10:10PM    1
# 10:15AM    1
# 11:40AM    1
# 7:11PM     1
# 1:50PM     1
# Name: Time, dtype: int64

# %%
# question 10
s = pd.value_counts(mydata['id'].values, sort=True)
print ("Number of repeated patients are ",str(len(s[s > 1])))
# Out:
# ('Number of repeated patients are ', '37')

# %%
# question 11
print "IDs of repeated visitors are: \n", s[s > 1]
# Out:
# IDs of repeated visitors are:
# 1      12
# 46      5
# 122     5
# 140     4
# 94      4
# 17      4
# 45      3
# 101     3
# 63      3
# 132     3
# 114     3
# 109     3
# 107     3
# 145     3
# 20      2
# 97      2
# 59      2
# 88      2
# 96      2
# 112     2
# 116     2
# 118     2
# 25      2
# 80      2
# 120     2
# 40      2
# 100     2
# 64      2
# 4       2
# 133     2
# 12      2
# 13      2
# 150     2
# 149     2
# 151     2
# 130     2
# 153     2
# dtype: int64

# %%
# question 12
s = mydata.groupby(['id']).Specialty.value_counts()
print s[s > 1]
# Out:
# id   Specialty
# 12   Dentist            2
# 13   Orthopedic         2
# 17   Dentist            2
# 25   Gynae              2
# 40   Dentist            2
# 45   Dentist            3
# 63   Dentist            2
# 88   Dentist            2
# 96   Dentist            2
# 97   Psychotherapist    2
# 100  Dentist            2
# 101  Gynae              3
# 107  Dentist            2
# 109  Dentist            3
# 112  Orthopedic         2
# 114  Gynae              3
# 116  Dentist            2
# 120  M/o                2
# 130  Psychotherapist    2
# 132  Dentist            3
# 140  Dentist            4
# 145  Dentist            3
# 149  Dentist            2
# 151  Dentist            2
# 153  Dentist            2
# Name: Specialty, dtype: int64

# %%
# question 13
mydata.Age = pd.to_numeric(mydata['Age'], errors='coerce')
mydata.groupby('Sex')['Age'].median()
# Out:
# Sex
# -       NaN
# f      30.0
# m      29.0
# nan     NaN
# Name: Age, dtype: float64

# %%
# question 14
mydata.replace(to_replace=mydata['AmountBalance'].unique()[0], value=np.nan, inplace=True)
mydata['AmountBalance']=mydata['AmountBalance'].map(lambda x: str(x).replace(',',''))
mydata['AmountBalance'] = mydata['AmountBalance'].astype(float)
print(mydata['AmountBalance'].sum())
# Out:
# 222500.0

# %%
# question 15
print mydata.TotalCharges[mydata.Procedure == "Consultation"].sum()
# Out:
# 83950.0

# %%
# question 16
mydata.corr().loc[['Age'],['TotalCharges']]
# Out:
#      TotalCharges
# Age       0.02809

# %%
# question 17
print str(int(mydata.Age.value_counts().idxmax()))
# Out:
# 30

# %%
# question 18
print str(mydata[(mydata.Procedure== 'X Rays') | (mydata.Procedure == 'Scalling')]['TotalCharges'].sum())
# Out:
# 16500.0
